# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np

# %%
samples = np.fromfile('rand.dat', sep=' ')

# %%
fig, ax = plt.subplots(figsize=(5, 5))

ax.scatter(samples[0::2], samples[1::2], lw=0, s=1, color='black')
ax.set_aspect('equal')

pass
